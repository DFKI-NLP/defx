# %%
import pandas as pd

# %%
initial_crf_tagger_bert_no_chars = {'B-Alias-Term': {'f1-score': 0.4217687074829932, 'precision': 0.37349397590361444, 'recall': 0.484375, 'support': 64}, 'B-Definition': {'f1-score': 0.6636500754147812, 'precision': 0.6666666666666666, 'recall': 0.6606606606606606, 'support': 666}, 'B-Qualifier': {'f1-score': 0.18181818181818182, 'precision': 0.3333333333333333, 'recall': 0.125, 'support': 16}, 'B-Referential-Definition': {'f1-score': 0.375, 'precision': 0.42857142857142855, 'recall': 0.3333333333333333, 'support': 18}, 'B-Referential-Term': {'f1-score': 0.3, 'precision': 0.42857142857142855, 'recall': 0.23076923076923078, 'support': 13}, 'B-Term': {'f1-score': 0.7245791245791245, 'precision': 0.682741116751269, 'recall': 0.7718794835007173, 'support': 697}, 'I-Alias-Term': {'f1-score': 0.47761194029850745, 'precision': 0.6037735849056604, 'recall': 0.3950617283950617, 'support': 81}, 'I-Definition': {'f1-score': 0.7657702249353792, 'precision': 0.7477177531951456, 'recall': 0.7847159603246168, 'support': 8872}, 'I-Qualifier': {'f1-score': 0.3779527559055118, 'precision': 0.7058823529411765, 'recall': 0.25806451612903225, 'support': 93}, 'I-Referential-Definition': {'f1-score': 0.375, 'precision': 0.42857142857142855, 'recall': 0.3333333333333333, 'support': 36}, 'I-Referential-Term': {'f1-score': 0.3529411764705882, 'precision': 0.2727272727272727, 'recall': 0.5, 'support': 6}, 'I-Term': {'f1-score': 0.6884338682899834, 'precision': 0.6405767250257467, 'recall': 0.7440191387559809, 'support': 836}, 'macro avg': {'f1-score': 0.47537717126625423, 'precision': 0.5260522555970142, 'recall': 0.46843436543349726, 'support': 11398}, 'micro avg': {'f1-score': 0.7425954459852766, 'precision': 0.7249707504596357, 'recall': 0.7610984383225127, 'support': 11398}, 'weighted avg': {'f1-score': 0.7410486803198121, 'precision': 0.7249767435679234, 'recall': 0.7610984383225127, 'support': 11398}}

# %%
subtask2_df = pd.DataFrame(initial_crf_tagger_bert_no_chars).transpose()

# %%
subtask2_df
# Out:
#                           f1-score  precision    recall  support
# B-Alias-Term              0.421769   0.373494  0.484375     64.0
# B-Definition              0.663650   0.666667  0.660661    666.0
# B-Qualifier               0.181818   0.333333  0.125000     16.0
# B-Referential-Definition  0.375000   0.428571  0.333333     18.0
# B-Referential-Term        0.300000   0.428571  0.230769     13.0
# B-Term                    0.724579   0.682741  0.771879    697.0
# I-Alias-Term              0.477612   0.603774  0.395062     81.0
# I-Definition              0.765770   0.747718  0.784716   8872.0
# I-Qualifier               0.377953   0.705882  0.258065     93.0
# I-Referential-Definition  0.375000   0.428571  0.333333     36.0
# I-Referential-Term        0.352941   0.272727  0.500000      6.0
# I-Term                    0.688434   0.640577  0.744019    836.0
# macro avg                 0.475377   0.526052  0.468434  11398.0
# ...

# %%
pd.DataFrame({'AKA': {'f': 0.9256198347107439,
         'p': 0.9180327868852459,
         'r': 0.9333333333333333},
 'Direct-Defines': {'f': 0.9316239316239316,
                    'p': 0.9211267605633803,
                    'r': 0.9423631123919308},
 'Indirect-Defines': {'f': 0.888888888888889,
                      'p': 0.8275862068965517,
                      'r': 0.96},
 'Qualifies': {'f': 0, 'p': 0, 'r': 0},
 'Refers-To': {'f': 0, 'p': 0.0, 'r': 0.0},
 'macro': {'f': 0.5492265310447129,
           'p': 0.5333491508690356,
           'r': 0.5671392891450528}}).transpose()
# Out:
#                          f         p         r
# AKA               0.925620  0.918033  0.933333
# Direct-Defines    0.931624  0.921127  0.942363
# Indirect-Defines  0.888889  0.827586  0.960000
# Qualifies         0.000000  0.000000  0.000000
# Refers-To         0.000000  0.000000  0.000000
# macro             0.549227  0.533349  0.567139

# %%
pd.DataFrame({'B-Alias-Term': {'f1-score': 0.41333333333333333,
                  'precision': 0.36046511627906974,
                  'recall': 0.484375,
                  'support': 64},
 'B-Definition': {'f1-score': 0.6720947446336047,
                  'precision': 0.6627737226277373,
                  'recall': 0.6816816816816816,
                  'support': 666},
 'B-Qualifier': {'f1-score': 0.3076923076923077,
                 'precision': 0.4,
                 'recall': 0.25,
                 'support': 16},
 'B-Referential-Definition': {'f1-score': 0.5,
                              'precision': 0.5,
                              'recall': 0.5,
                              'support': 18},
 'B-Referential-Term': {'f1-score': 0.21052631578947367,
                        'precision': 0.3333333333333333,
                        'recall': 0.15384615384615385,
                        'support': 13},
 'B-Term': {'f1-score': 0.739193083573487,
            'precision': 0.7424023154848046,
            'recall': 0.7360114777618364,
            'support': 697},
 'I-Alias-Term': {'f1-score': 0.5034965034965034,
                  'precision': 0.5806451612903226,
                  'recall': 0.4444444444444444,
                  'support': 81},
 'I-Definition': {'f1-score': 0.75923513781066,
                  'precision': 0.7059393469625036,
                  'recall': 0.8212353471596032,
                  'support': 8872},
 'I-Qualifier': {'f1-score': 0.4102564102564103,
                 'precision': 0.5079365079365079,
                 'recall': 0.34408602150537637,
                 'support': 93},
 'I-Referential-Definition': {'f1-score': 0.463768115942029,
                              'precision': 0.48484848484848486,
                              'recall': 0.4444444444444444,
                              'support': 36},
 'I-Referential-Term': {'f1-score': 0.3636363636363636,
                        'precision': 0.4,
                        'recall': 0.3333333333333333,
                        'support': 6},
 'I-Term': {'f1-score': 0.6883343006384214,
            'precision': 0.6685456595264938,
            'recall': 0.7093301435406698,
            'support': 836},
 'macro avg': {'f1-score': 0.5026305514002162,
               'precision': 0.5289074706907716,
               'recall': 0.4918990039764619,
               'support': 11398},
 'micro avg': {'f1-score': 0.7399958788378324,
               'precision': 0.6977539441983368,
               'recall': 0.7876820494823653,
               'support': 11398},
 'weighted avg': {'f1-score': 0.7382998844377139,
                  'precision': 0.6964193516679077,
                  'recall': 0.7876820494823653,
                  'support': 11398}}).transpose()
# Out:
#                           f1-score  precision    recall  support
# B-Alias-Term              0.413333   0.360465  0.484375     64.0
# B-Definition              0.672095   0.662774  0.681682    666.0
# B-Qualifier               0.307692   0.400000  0.250000     16.0
# B-Referential-Definition  0.500000   0.500000  0.500000     18.0
# B-Referential-Term        0.210526   0.333333  0.153846     13.0
# B-Term                    0.739193   0.742402  0.736011    697.0
# I-Alias-Term              0.503497   0.580645  0.444444     81.0
# I-Definition              0.759235   0.705939  0.821235   8872.0
# I-Qualifier               0.410256   0.507937  0.344086     93.0
# I-Referential-Definition  0.463768   0.484848  0.444444     36.0
# I-Referential-Term        0.363636   0.400000  0.333333      6.0
# I-Term                    0.688334   0.668546  0.709330    836.0
# macro avg                 0.502631   0.528907  0.491899  11398.0
# ...

# %%
pd.DataFrame({'AKA': {'f': 0.4444444444444444,
         'p': 0.5641025641025641,
         'r': 0.36666666666666664},
 'Direct-Defines': {'f': 0.6508379888268156,
                    'p': 0.6314363143631436,
                    'r': 0.6714697406340058},
 'Indirect-Defines': {'f': 0.5263157894736842,
                      'p': 0.7692307692307693,
                      'r': 0.4},
 'Qualifies': {'f': 0, 'p': 0, 'r': 0},
 'Refers-To': {'f': 0, 'p': 0, 'r': 0.0},
 'macro': {'f': 0.3243196445489888,
           'p': 0.3929539295392954,
           'r': 0.2876272814601345}}).transpose()
# Out:
#                          f         p         r
# AKA               0.444444  0.564103  0.366667
# Direct-Defines    0.650838  0.631436  0.671470
# Indirect-Defines  0.526316  0.769231  0.400000
# Qualifies         0.000000  0.000000  0.000000
# Refers-To         0.000000  0.000000  0.000000
# macro             0.324320  0.392954  0.287627
